# %%
import os

def count_files(path):
    file_count = sum([len(files) for r, d, files in os.walk(path)])
    return file_count

def mahek():
    main_folder_path = "2_Datasets/Dataset1/train/"
    folders = os.listdir(main_folder_path)
    folder_file_counts = [(folder, count_files(os.path.join(main_folder_path, folder))) for folder in folders]
    sorted_folder_file_counts = sorted(folder_file_counts, key=lambda x: x[1], reverse=True)
    
    for folder, file_count in sorted_folder_file_counts:
        print(f"{folder}: {file_count}")
        
if __name__ == '__main__':
    mahek()
# Out:
# HOUSE FINCH: 248
# OVENBIRD: 233
# D-ARNAUDS BARBET: 233
# SWINHOES PHEASANT: 217
# WOOD DUCK: 214
# CASPIAN TERN: 213
# RED BILLED TROPICBIRD: 212
# WOOD THRUSH: 211
# MERLIN: 209
# FRILL BACK PIGEON: 209
# PYRRHULOXIA: 209
# ORNATE HAWK EAGLE: 208
# MILITARY MACAW: 208
# LAUGHING GULL: 208
# OYSTER CATCHER: 207
# EASTERN YELLOW ROBIN: 205
# JACOBIN PIGEON: 204
# DARK EYED JUNCO: 203
# GREATER PRAIRIE CHICKEN: 203
# RED TAILED HAWK: 202
# VIOLET GREEN SWALLOW: 201
# VIOLET BACKED STARLING: 201
# RED KNOT: 200
# PLUSH CRESTED JAY: 200
# SORA: 200
# LIMPKIN: 200
# CRIMSON SUNBIRD: 198
# CAMPO FLICKER: 197
# ROSE BREASTED COCKATOO: 197
# SAYS PHOEBE: 197
# RED BEARDED BEE EATER: 197
# MARABOU STORK: 197
# CRESTED WOOD PARTRIDGE: 197
# STRIATED CARACARA: 196
# NORTHERN PARULA: 196
# WILLOW PTARMIGAN: 196
# BLUE GRAY GNATCATCHER: 195
# RAZORBILL: 194
# BANDED BROADBILL: 194
# ROSEATE SPOONBILL: 193
# WRENTIT: 193
# VARIED THRUSH: 193
# PALM NUT VULTURE: 192
# BROWN HEADED COWBIRD: 192
# ...

# %%
# !ls
# Out:
# 1. Project_Proposal
# 2023-02-07 21.39.33 AI Project
# 2_Datasets
# CS-AI-Project-master_Rushi
# DatasetBefore_After_GroupF.xlsx
# comp6721_project_guideline_winter2023.pdf
# count.ipynb
# ~$DatasetBefore_After_GroupF.xlsx

# %%
import os

# Function to count the number of files in a directory
def count_files(path):
    count = 0
    for root, dirs, files in os.walk(path):
        count += len(files)
    return count

# Main directory path
main_dir_path = "/Users/mahekmaster/Desktop/Mahek's Space/ConcordiaStudy/AIWINTER2023/AI_Project/2_Datasets/Dataset3/train_data/train_data"

# Get the count of files in each subdirectory
sub_dir_counts = {}
for root, dirs, files in os.walk(main_dir_path):
    for dir in dirs:
        dir_path = os.path.join(root, dir)
        sub_dir_counts[dir_path] = count_files(dir_path)

# Sort the subdirectories by count of files in descending order
sorted_dirs = sorted(sub_dir_counts.items(), key=lambda x: x[1], reverse=True)

# Write the information of the top 30 directories in a text file
with open("top_10_folders.txt", "w") as f:
    for i, (dir_path, count) in enumerate(sorted_dirs[:10]):
        f.write(f"{i+1}. {dir_path} - {count} files\n")

# %%
import os

# Function to count the number of files in a directory
def count_files(path):
    count = 0
    for root, dirs, files in os.walk(path):
        count += len(files)
    return count

# Main directory path
main_dir_path = "/Users/mahekmaster/Desktop/Mahek's Space/ConcordiaStudy/AIWINTER2023/AI_Project/2_Datasets/Dataset2/CUB_200_2011/CUB_200_2011/images"

# Get the count of files in each subdirectory
sub_dir_counts = {}
for root, dirs, files in os.walk(main_dir_path):
    for dir in dirs:
        dir_path = os.path.join(root, dir)
        sub_dir_counts[dir_path] = count_files(dir_path)

# Sort the subdirectories by count of files in descending order
sorted_dirs = sorted(sub_dir_counts.items(), key=lambda x: x[1], reverse=True)

# Write the information of the top 30 directories in a text file
with open("top_30_folders.txt", "w") as f:
    for i, (dir_path, count) in enumerate(sorted_dirs[:30]):
        f.write(f"{i+1}. {dir_path} - {count} files\n")
